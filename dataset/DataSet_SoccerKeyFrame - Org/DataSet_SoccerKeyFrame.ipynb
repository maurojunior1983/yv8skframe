# %%
import csv

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_frame", "end_frame", "description"])

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_with_ads = f"{video_path_with_ads}video_with_ads_{i}.mp4"
    # Exemplo de duas propagandas por vídeo
    data.append([video_with_ads, 30 + i * 10, 90 + i * 10, "Comercial de refrigerante"])
    data.append([video_with_ads, 150 + i * 10, 210 + i * 10, "Propaganda de carro"])

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"{video_path_without_ads}video_without_ads_{i}.mp4"
    data.append([video_without_ads, None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_frame", "end_frame", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Exemplo de nome de arquivo
    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1]
        minutes, seconds, frames = map(int, time_part.split('_'))
        
        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30
        
        # Calcular tempo final em frames
        end_frame = (minutes * 60 + end_seconds) * 30 + end_frames

        # Adicionar dados à lista
        data.append([os.path.join(video_path_with_ads, video_name), start_frame, end_frame, "Comercial de refrigerante"])

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30864\1436640699.py in <module>
#      21     if len(parts) == 2:
#      22         time_part = parts[1]
# ---> 23         minutes, seconds, frames = map(int, time_part.split('_'))
#      24
#      25         # Calcular tempo de início em frames
#
# ValueError: invalid literal for int() with base 10: '11.mp4'

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_frame", "end_frame", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11"  # Nome do arquivo sem a extensão
    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1]
        minutes, seconds, frames = map(int, time_part.split('_'))
        
        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30
        
        # Calcular tempo final em frames
        end_frame = (minutes * 60 + end_seconds) * 30 + end_frames

        # Adicionar dados à lista
        data.append([os.path.join(video_path_with_ads, video_name + ".mp4"), start_frame, end_frame, "Comercial de refrigerante"])

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_frame", "end_frame", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Exemplo de nome de arquivo
    # Extrair tempo do nome do arquivo
    # O formato esperado para o tempo é a parte após '-T_'
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1]  # Pega a parte do tempo
        minutes, seconds, frames = map(int, time_part.split('_'))

        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo 30 fps
        
        # Calcular tempo final
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30
            
        # Calcular tempo final em frames
        end_frame = (minutes * 60 + end_seconds) * 30 + end_frames

        # Adicionar dados à lista com o nome do arquivo completo
        data.append([os.path.join(video_path_with_ads, video_name), start_frame, end_frame, "Comercial de refrigerante"])

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30864\194792537.py in <module>
#      22     if len(parts) == 2:
#      23         time_part = parts[1]  # Pega a parte do tempo
# ---> 24         minutes, seconds, frames = map(int, time_part.split('_'))
#      25
#      26         # Calcular tempo de início em frames
#
# ValueError: invalid literal for int() with base 10: '11.mp4'

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_frame", "end_frame", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Exemplo de nome de arquivo
    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1].replace(".mp4", "")  # Remove a extensão
        minutes, seconds, frames = map(int, time_part.split('_'))

        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
        
        # Calcular tempo final
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30
            
        # Calcular tempo final em frames
        end_frame = (minutes * 60 + end_seconds) * 30 + end_frames

        # Adicionar dados à lista
        data.append([os.path.join(video_path_with_ads, video_name), start_frame, end_frame, "Comercial de refrigerante"])

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Exemplo de nome de arquivo
    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1].replace(".mp4", "")  # Remove a extensão
        minutes, seconds, frames = map(int, time_part.split('_'))

        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

        # Calcular tempo final
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30

        end_minutes = minutes + end_seconds // 60
        end_seconds = end_seconds % 60

        # Adicionar dados à lista e imprimir os tempos
        start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
        end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
        data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
        print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Vídeo: C_FOG_1-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_2-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_3-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_4-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_5-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_6-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_7-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_8-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_9-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_10-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_11-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_12-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_13-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_14-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_15-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_16-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_17-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_18-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_19-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_20-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_21-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_22-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_23-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_24-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_25-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_26-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_27-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_28-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_29-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_30-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Substitua isso pelos nomes reais se tiver

    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1].replace(".mp4", "")  # Remove a extensão
        minutes, seconds, frames = map(int, time_part.split('_'))

        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
        
        # Calcular tempo final
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30

        end_minutes = minutes + end_seconds // 60
        end_seconds = end_seconds % 60

        # Adicionar dados à lista e imprimir os tempos
        start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
        end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
        data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
        print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Vídeo: C_FOG_1-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_2-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_3-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_4-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_5-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_6-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_7-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_8-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_9-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_10-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_11-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_12-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_13-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_14-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_15-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_16-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_17-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_18-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_19-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_20-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_21-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_22-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_23-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_24-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_25-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_26-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_27-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_28-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_29-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_30-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando 30 vídeos com propagandas
for i in range(1, 31):
    # Ajuste: Defina o nome do arquivo com base na posição 'i'
    video_name = f"C_FOG_{i}-T_01_12_11.mp4"  # Placeholder para o padrão real
    # Para fins de teste, você poderia trocar para os nomes reais, como:
    # video_name = f"C_FOG_{i}-T_0{min(i % 60)}_{1 + i % 30}_{1 + i % 30}.mp4"

    # Extrair tempo do nome do arquivo
    parts = video_name.split('-T_')
    if len(parts) == 2:
        time_part = parts[1].replace(".mp4", "")  # Remove a extensão
        minutes, seconds, frames = map(int, time_part.split('_'))

        # Calcular tempo de início em frames
        start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

        # Calcular tempo final
        end_seconds = seconds + duration_seconds
        end_frames = frames + duration_frames

        # Ajustar os segundos e frames
        if end_frames >= 30:
            end_seconds += end_frames // 30
            end_frames = end_frames % 30

        end_minutes = minutes + end_seconds // 60
        end_seconds = end_seconds % 60

        # Adicionar dados à lista e imprimir os tempos
        start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
        end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
        data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
        print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando 20 vídeos sem propagandas
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Vídeo: C_FOG_1-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_2-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_3-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_4-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_5-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_6-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_7-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_8-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_9-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_10-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_11-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_12-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_13-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_14-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_15-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_16-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_17-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_18-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_19-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_20-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_21-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_22-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_23-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_24-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_25-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_26-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_27-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_28-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_29-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: C_FOG_30-T_01_12_11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando vídeos com propagandas a partir do diretório
for video_name in os.listdir(video_path_with_ads):
    if video_name.endswith(".mp4"):  # Certifica que estamos lidando apenas com arquivos MP4
        # Extrair tempo do nome do arquivo
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            minutes, seconds, frames = map(int, time_part.split('_'))

            # Calcular tempo de início em frames
            start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo 30 fps
            
            # Calcular tempo final
            end_seconds = seconds + duration_seconds
            end_frames = frames + duration_frames

            # Ajustar os segundos e frames
            if end_frames >= 30:
                end_seconds += end_frames // 30
                end_frames = end_frames % 30

            end_minutes = minutes + end_seconds // 60
            end_seconds = end_seconds % 60

            # Adicionar dados à lista e imprimir os tempos
            start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
            end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
            data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando 20 vídeos sem propagandas 
# (aqui você pode substituir por seus próprios vídeos)
for i in range(1, 21):
    video_without_ads = f"video_without_ads_{i}.mp4"
    data.append([os.path.join(video_path_without_ads, video_without_ads), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando vídeos com propagandas
for video_name in os.listdir(video_path_with_ads):
    if video_name.endswith(".mp4"):  # Certifique-se de processar apenas arquivos MP4
        # Extrair tempo do nome do arquivo
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            minutes, seconds, frames = map(int, time_part.split('_'))

            # Calcular tempo de início em frames
            start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
            
            # Calcular tempo final
            end_seconds = seconds + duration_seconds
            end_frames = frames + duration_frames

            # Ajustar os segundos e frames
            if end_frames >= 30:
                end_seconds += end_frames // 30
                end_frames = end_frames % 30

            end_minutes = minutes + end_seconds // 60
            end_seconds = end_seconds % 60

            # Adicionar dados à lista e imprimir os tempos
            start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
            end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
            data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando vídeos sem propagandas
for video_name in os.listdir(video_path_without_ads):
    if video_name.endswith(".mp4"):  # Certifique-se de processar apenas arquivos MP4
        data.append([os.path.join(video_path_without_ads, video_name), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_path_with_ads = "C:/VIDEO_INSER_GRAFICA_2/C_FOG/"
video_path_without_ads = "C:/VIDEO_INSER_GRAFICA_2/S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando vídeos com propagandas
for video_name in os.listdir(video_path_with_ads):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        # O nome do arquivo está no formato CFOG1T_00-28-18.mp4
        parts = video_name.split('T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            minutes, seconds, frames = map(int, time_part.split('-'))

            # Calcular tempo de início em frames
            start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
            
            # Calcular tempo final
            end_seconds = seconds + duration_seconds
            end_frames = frames + duration_frames

            # Ajustar os segundos e frames
            if end_frames >= 30:
                end_seconds += end_frames // 30
                end_frames = end_frames % 30

            end_minutes = minutes + end_seconds // 60
            end_seconds = end_seconds % 60

            # Formatar os tempos
            start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
            end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
            # Adicionar dados à lista
            data.append([os.path.join(video_path_with_ads, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando vídeos sem propagandas
for video_name in os.listdir(video_path_without_ads):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        data.append([os.path.join(video_path_without_ads, video_name), None, None, "Sem propaganda"])

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# Vídeo: CFOG01T_00-28-18.mp4 | Início: 00:28:18 | Fim: 00:36:10
# Vídeo: CFOG02T_00-11-26.mp4 | Início: 00:11:26 | Fim: 00:19:18
# Vídeo: CFOG03T_01-26-01.mp4 | Início: 01:26:01 | Fim: 01:33:23
# Vídeo: CFOG04T_00-10-16.mp4 | Início: 00:10:16 | Fim: 00:18:08
# Vídeo: CFOG05T_00-18-04.mp4 | Início: 00:18:04 | Fim: 00:25:26
# Vídeo: CFOG06T_01-49-28.mp4 | Início: 01:49:28 | Fim: 01:57:20
# Vídeo: CFOG07T_01-10-00.mp4 | Início: 01:10:00 | Fim: 01:17:22
# Vídeo: CFOG08T_00-40-00.mp4 | Início: 00:40:00 | Fim: 00:47:22
# Vídeo: CFOG09T_00-48-07.mp4 | Início: 00:48:07 | Fim: 00:55:29
# Vídeo: CFOG10T_00-53-13.mp4 | Início: 00:53:13 | Fim: 01:01:05
# Vídeo: CFOG11T_01-12-11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# Vídeo: CFOG12T_01-03-15.mp4 | Início: 01:03:15 | Fim: 01:11:07
# Vídeo: CFOG13T_01-00-16.mp4 | Início: 01:00:16 | Fim: 01:08:08
# Vídeo: CFOG14T_01-42-15.mp4 | Início: 01:42:15 | Fim: 01:50:07
# Vídeo: CFOG15T_01-35-00.mp4 | Início: 01:35:00 | Fim: 01:42:22
# Vídeo: CFOG16T_01-39-15.mp4 | Início: 01:39:15 | Fim: 01:47:07
# Vídeo: CFOG17T_01-20-11.mp4 | Início: 01:20:11 | Fim: 01:28:03
# Vídeo: CFOG18T_01-18-07.mp4 | Início: 01:18:07 | Fim: 01:25:29
# Vídeo: CFOG19T_00-13-26.mp4 | Início: 00:13:26 | Fim: 00:21:18
# Vídeo: CFOG20T_00-15-00.mp4 | Início: 00:15:00 | Fim: 00:22:22
# Vídeo: CFOG21T_00-20-13.mp4 | Início: 00:20:13 | Fim: 00:28:05
# Vídeo: CFOG22T_00-30-15.mp4 | Início: 00:30:15 | Fim: 00:38:07
# Vídeo: CFOG23T_00-45-16.mp4 | Início: 00:45:16 | Fim: 00:53:08
# Vídeo: CFOG24T_00-55-09.mp4 | Início: 00:55:09 | Fim: 01:03:01
# Vídeo: CFOG25T_01-05-14.mp4 | Início: 01:05:14 | Fim: 01:13:06
# Vídeo: CFOG26T_01-15-07.mp4 | Início: 01:15:07 | Fim: 01:22:29
# Vídeo: CFOG27T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# Vídeo: CFOG28T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# Vídeo: CFOG29T_01-30-11.mp4 | Início: 01:30:11 | Fim: 01:38:03
# Vídeo: CFOG30T_01-40-09.mp4 | Início: 01:40:09 | Fim: 01:48:01
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos dos vídeos na pasta LEARN
video_path_with_ads_learn = "C:/VIDEO_INSER_GRAFICA_2/LEARN/LE_C_FOG/"
video_path_without_ads_learn = "C:/VIDEO_INSER_GRAFICA_2/LEARN/LE_S_FOG/"

# Caminhos dos vídeos na pasta CHECK
video_path_with_ads_check = "C:/VIDEO_INSER_GRAFICA_2/CHECK/CH_C_FOG/"
video_path_without_ads_check = "C:/VIDEO_INSER_GRAFICA_2/CHECK/CH_S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Adicionando vídeos com propagandas da pasta LEARN
for video_name in os.listdir(video_path_with_ads_learn):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        # Extrair tempo do nome do arquivo
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            minutes, seconds, frames = map(int, time_part.split('-'))

            # Calcular tempo de início em frames
            start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
            
            # Calcular tempo final
            end_seconds = seconds + duration_seconds
            end_frames = frames + duration_frames

            # Ajustar os segundos e frames
            if end_frames >= 30:
                end_seconds += end_frames // 30
                end_frames = end_frames % 30

            end_minutes = minutes + end_seconds // 60
            end_seconds = end_seconds % 60

            # Formatar os tempos
            start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
            end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
            # Adicionar dados à lista
            data.append([os.path.join(video_path_with_ads_learn, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"[LEARN] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando vídeos sem propagandas da pasta LEARN
for video_name in os.listdir(video_path_without_ads_learn):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        data.append([os.path.join(video_path_without_ads_learn, video_name), None, None, "Sem propaganda"])
        print(f"[LEARN] Vídeo: {video_name} | Sem propaganda")

# Adicionando vídeos com propagandas da pasta CHECK
for video_name in os.listdir(video_path_with_ads_check):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        # Extrair tempo do nome do arquivo
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            minutes, seconds, frames = map(int, time_part.split('-'))

            # Calcular tempo de início em frames
            start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps
            
            # Calcular tempo final
            end_seconds = seconds + duration_seconds
            end_frames = frames + duration_frames

            # Ajustar os segundos e frames
            if end_frames >= 30:
                end_seconds += end_frames // 30
                end_frames = end_frames % 30

            end_minutes = minutes + end_seconds // 60
            end_seconds = end_seconds % 60

            # Formatar os tempos
            start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
            end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
        
            # Adicionar dados à lista
            data.append([os.path.join(video_path_with_ads_check, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"[CHECK] Vídeo․․․
# Out:
#   File "C:\Users\mauron\AppData\Local\Temp\ipykernel_30864\4145936332.py", line 88
#     print(f"[CHECK] Vídeo․․․
#                             ^
# SyntaxError: EOL while scanning string literal

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_path_with_ads_learn = "C:/VIDEO_INSER_GRAFICA_2/LEARN/LE_C_FOG/"
video_path_without_ads_learn = "C:/VIDEO_INSER_GRAFICA_2/LEARN/LE_S_FOG/"
video_path_with_ads_check = "C:/VIDEO_INSER_GRAFICA_2/CHECK/CH_C_FOG/"
video_path_without_ads_check = "C:/VIDEO_INSER_GRAFICA_2/CHECK/CH_S_FOG/"

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do nome do arquivo
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))
    
    # Calcular o tempo de início em frames
    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    # Calcular o tempo final
    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    # Ajustar os segundos e frames
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    # Formatar os tempos
    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    
    return start_frame, start_time, end_time

# Adicionando vídeos com propagandas da pasta LEARN
for video_name in os.listdir(video_path_with_ads_learn):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            start_frame, start_time, end_time = calculate_times(time_part)
        
            # Adicionar dados à lista
            data.append([os.path.join(video_path_with_ads_learn, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"[LEARN] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando vídeos sem propagandas da pasta LEARN
for video_name in os.listdir(video_path_without_ads_learn):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        data.append([os.path.join(video_path_without_ads_learn, video_name), None, None, "Sem propaganda"])
        print(f"[LEARN] Vídeo: {video_name} | Sem propaganda")

# Adicionando vídeos com propagandas da pasta CHECK
for video_name in os.listdir(video_path_with_ads_check):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        parts = video_name.split('-T_')
        if len(parts) == 2:
            time_part = parts[1].replace(".mp4", "")  # Remove a extensão
            start_frame, start_time, end_time = calculate_times(time_part)
            
            # Adicionar dados à lista
            data.append([os.path.join(video_path_with_ads_check, video_name), start_time, end_time, "Comercial de refrigerante"])
            print(f"[CHECK] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

# Adicionando vídeos sem propagandas da pasta CHECK
for video_name in os.listdir(video_path_without_ads_check):
    if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
        data.append([os.path.join(video_path_without_ads_check, video_name), None, None, "Sem propaganda"])
        print(f"[CHECK] Vídeo: {video_name} | Sem propaganda")

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# [LEARN] Vídeo: SEM_FOG_01.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_03.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_05.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_06.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_08.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_10.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_11.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_13.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_15.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_16.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_18.mp4 | Sem propaganda
# [LEARN] Vídeo: SEM_FOG_20.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_02.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_04.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_07.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_09.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_12.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_14.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_17.mp4 | Sem propaganda
# [CHECK] Vídeo: SEM_FOG_19.mp4 | Sem propaganda
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
folders = {
    "LEARN": {
        "with_ads": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
        "without_ads": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/"
    },
    "CHECK": {
        "with_ads": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
        "without_ads": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
    }
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do nome do arquivo
def calculate_times(time_part):
    """Calcula o tempo de início e fim da propaganda."""
    minutes, seconds, frames = map(int, time_part.split('-'))
    
    # Calcular o tempo de início em frames
    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    # Calcular o tempo final
    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    # Ajustar os segundos e frames
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    return start_frame, (end_minutes, end_seconds, end_frames)

# Processar vídeos com e sem propagandas nas pastas LEARN e CHECK
for phase in ["LEARN", "CHECK"]:
    for video_type in ["with_ads", "without_ads"]:
        video_path = folders[phase][video_type]
        
        for video_name in os.listdir(video_path):
            if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
                if video_type == "with_ads":  # Vídeos com propagandas
                    # Extrair tempo do nome do arquivo
                    parts = video_name.split('T_')
                    if len(parts) == 2:
                        time_part = parts[1].replace(".mp4", "")  # Remove a extensão
                        start_frame, (end_minutes, end_seconds, end_frames) = calculate_times(time_part)
                        
                        # Formatar os tempos
                        start_time = f"{int(parts[0][5:7]):02}:{int(parts[0][8:10]):02}:{int(parts[0][11:]):02}"  # MM:SS:FF
                        end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
                        
                        # Adicionar dados à lista
                        data.append([os.path.join(video_path, video_name), start_time, end_time, "Comercial de refrigerante"])
                        print(f"[{phase}] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")

                elif video_type == "without_ads":  # Vídeos sem propagandas
                    data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                    print(f"[{phase}] Vídeo: {video_name} | Sem propaganda")

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12412\4197320836.py in <module>
#      59
#      60                         # Formatar os tempos
# ---> 61                         start_time = f"{int(parts[0][5:7]):02}:{int(parts[0][8:10]):02}:{int(parts[0][11:]):02}"  # MM:SS:FF
#      62                         end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
#      63
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do nome do arquivo
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))
    
    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    
    return start_frame, start_time, end_time

# Função para listar vídeos e coletar dados
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            if with_ads:  # Vídeos com propaganda
                parts = video_name.split('-T_')
                if len(parts) == 2:
                    time_part = parts[1].replace(".mp4", "")
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([os.path.join(video_path, video_name), start_time, end_time, "Comercial de refrigerante"])
                    print(f"[COM] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")
            else:  # Vídeos sem propaganda
                data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                print(f"[SEM] Vídeo: {video_name} | Sem propaganda")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# [SEM] Vídeo: SEM_FOG_01.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_03.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_05.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_06.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_08.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_10.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_11.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_13.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_15.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_16.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_18.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_20.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_02.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_04.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_07.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_09.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_12.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_14.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_17.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_19.mp4 | Sem propaganda
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do nome do arquivo
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))
    
    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    
    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            if with_ads:  # Vídeos com propaganda
                parts = video_name.split('-T_')
                if len(parts) == 2 and len(parts[1].split('.mp4')[0]) == 8:  # Certifica-se de que existem 8 caracteres antes da extensão
                    time_part = parts[1].replace(".mp4", "")
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([os.path.join(video_path, video_name), start_time, end_time, "Comercial de refrigerante"])
                    print(f"[COM] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                print(f"[SEM] Vídeo: {video_name} | Sem propaganda")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# [ERRO] Vídeo com propaganda mal formatado: CFOG01T_00-28-18.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG03T_01-26-01.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG05T_00-18-04.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG06T_01-49-28.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG08T_00-40-00.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG10T_00-53-13.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG11T_01-12-11.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG13T_01-00-16.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG15T_01-35-00.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG16T_01-39-15.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG18T_01-18-07.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG20T_00-15-00.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG21T_00-20-13.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG23T_00-45-16.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG25T_01-05-14.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG26T_01-15-07.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG28T_01-28-13.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG30T_01-40-09.mp4
# [SEM] Vídeo: SEM_FOG_01.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_03.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_05.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_06.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_08.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_10.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_11.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_13.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_15.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_16.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_18.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_20.mp4 | Sem propaganda
# [ERRO] Vídeo com propaganda mal formatado: CFOG02T_00-11-26.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG04T_00-10-16.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG07T_01-10-00.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG09T_00-48-07.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG12T_01-03-15.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG14T_01-42-15.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG17T_01-20-11.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG19T_00-13-26.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG22T_00-30-15.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG24T_00-55-09.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG27T_01-28-13.mp4
# [ERRO] Vídeo com propaganda mal formatado: CFOG29T_01-30-11.mp4
# [SEM] Vídeo: SEM_FOG_02.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_04.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_07.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_09.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_12.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_14.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_17.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_19.mp4 | Sem propaganda
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([os.path.join(video_path, video_name), start_time, end_time, "Comercial de refrigerante"])
                    print(f"[COM] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                    print(f"[SEM] Vídeo: {video_name} | Sem propaganda")
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Salvando arquivo CSV
with open('anotacoes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo anotações.csv gerado com sucesso!")
# Out:
# [COM] Vídeo: CFOG01T_00-28-18.mp4 | Início: 00:28:18 | Fim: 00:36:10
# [COM] Vídeo: CFOG03T_01-26-01.mp4 | Início: 01:26:01 | Fim: 01:33:23
# [COM] Vídeo: CFOG05T_00-18-04.mp4 | Início: 00:18:04 | Fim: 00:25:26
# [COM] Vídeo: CFOG06T_01-49-28.mp4 | Início: 01:49:28 | Fim: 01:57:20
# [COM] Vídeo: CFOG08T_00-40-00.mp4 | Início: 00:40:00 | Fim: 00:47:22
# [COM] Vídeo: CFOG10T_00-53-13.mp4 | Início: 00:53:13 | Fim: 01:01:05
# [COM] Vídeo: CFOG11T_01-12-11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# [COM] Vídeo: CFOG13T_01-00-16.mp4 | Início: 01:00:16 | Fim: 01:08:08
# [COM] Vídeo: CFOG15T_01-35-00.mp4 | Início: 01:35:00 | Fim: 01:42:22
# [COM] Vídeo: CFOG16T_01-39-15.mp4 | Início: 01:39:15 | Fim: 01:47:07
# [COM] Vídeo: CFOG18T_01-18-07.mp4 | Início: 01:18:07 | Fim: 01:25:29
# [COM] Vídeo: CFOG20T_00-15-00.mp4 | Início: 00:15:00 | Fim: 00:22:22
# [COM] Vídeo: CFOG21T_00-20-13.mp4 | Início: 00:20:13 | Fim: 00:28:05
# [COM] Vídeo: CFOG23T_00-45-16.mp4 | Início: 00:45:16 | Fim: 00:53:08
# [COM] Vídeo: CFOG25T_01-05-14.mp4 | Início: 01:05:14 | Fim: 01:13:06
# [COM] Vídeo: CFOG26T_01-15-07.mp4 | Início: 01:15:07 | Fim: 01:22:29
# [COM] Vídeo: CFOG28T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# [COM] Vídeo: CFOG30T_01-40-09.mp4 | Início: 01:40:09 | Fim: 01:48:01
# [SEM] Vídeo: SEM_FOG_01.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_03.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_05.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_06.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_08.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_10.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_11.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_13.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_15.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_16.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_18.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_20.mp4 | Sem propaganda
# [COM] Vídeo: CFOG02T_00-11-26.mp4 | Início: 00:11:26 | Fim: 00:19:18
# [COM] Vídeo: CFOG04T_00-10-16.mp4 | Início: 00:10:16 | Fim: 00:18:08
# [COM] Vídeo: CFOG07T_01-10-00.mp4 | Início: 01:10:00 | Fim: 01:17:22
# [COM] Vídeo: CFOG09T_00-48-07.mp4 | Início: 00:48:07 | Fim: 00:55:29
# [COM] Vídeo: CFOG12T_01-03-15.mp4 | Início: 01:03:15 | Fim: 01:11:07
# [COM] Vídeo: CFOG14T_01-42-15.mp4 | Início: 01:42:15 | Fim: 01:50:07
# [COM] Vídeo: CFOG17T_01-20-11.mp4 | Início: 01:20:11 | Fim: 01:28:03
# [COM] Vídeo: CFOG19T_00-13-26.mp4 | Início: 00:13:26 | Fim: 00:21:18
# [COM] Vídeo: CFOG22T_00-30-15.mp4 | Início: 00:30:15 | Fim: 00:38:07
# [COM] Vídeo: CFOG24T_00-55-09.mp4 | Início: 00:55:09 | Fim: 01:03:01
# [COM] Vídeo: CFOG27T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# [COM] Vídeo: CFOG29T_01-30-11.mp4 | Início: 01:30:11 | Fim: 01:38:03
# [SEM] Vídeo: SEM_FOG_02.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_04.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_07.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_09.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_12.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_14.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_17.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_19.mp4 | Sem propaganda
# Arquivo anotações.csv gerado com sucesso!

# %%
import csv
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([os.path.join(video_path, video_name), start_time, end_time, "Informar Patrocinador"])
                    print(f"[COM] Vídeo: {video_name} | Início: {start_time} | Fim: {end_time}")
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                    print(f"[SEM] Vídeo: {video_name} | Sem propaganda")
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Salvando arquivo CSV com o novo nome
with open('DataSet_SoccerKeyFrame.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("Arquivo DataSet_SoccerKeyFrame.csv gerado com sucesso!")
# Out:
# [COM] Vídeo: CFOG01T_00-28-18.mp4 | Início: 00:28:18 | Fim: 00:36:10
# [COM] Vídeo: CFOG03T_01-26-01.mp4 | Início: 01:26:01 | Fim: 01:33:23
# [COM] Vídeo: CFOG05T_00-18-04.mp4 | Início: 00:18:04 | Fim: 00:25:26
# [COM] Vídeo: CFOG06T_01-49-28.mp4 | Início: 01:49:28 | Fim: 01:57:20
# [COM] Vídeo: CFOG08T_00-40-00.mp4 | Início: 00:40:00 | Fim: 00:47:22
# [COM] Vídeo: CFOG10T_00-53-13.mp4 | Início: 00:53:13 | Fim: 01:01:05
# [COM] Vídeo: CFOG11T_01-12-11.mp4 | Início: 01:12:11 | Fim: 01:20:03
# [COM] Vídeo: CFOG13T_01-00-16.mp4 | Início: 01:00:16 | Fim: 01:08:08
# [COM] Vídeo: CFOG15T_01-35-00.mp4 | Início: 01:35:00 | Fim: 01:42:22
# [COM] Vídeo: CFOG16T_01-39-15.mp4 | Início: 01:39:15 | Fim: 01:47:07
# [COM] Vídeo: CFOG18T_01-18-07.mp4 | Início: 01:18:07 | Fim: 01:25:29
# [COM] Vídeo: CFOG20T_00-15-00.mp4 | Início: 00:15:00 | Fim: 00:22:22
# [COM] Vídeo: CFOG21T_00-20-13.mp4 | Início: 00:20:13 | Fim: 00:28:05
# [COM] Vídeo: CFOG23T_00-45-16.mp4 | Início: 00:45:16 | Fim: 00:53:08
# [COM] Vídeo: CFOG25T_01-05-14.mp4 | Início: 01:05:14 | Fim: 01:13:06
# [COM] Vídeo: CFOG26T_01-15-07.mp4 | Início: 01:15:07 | Fim: 01:22:29
# [COM] Vídeo: CFOG28T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# [COM] Vídeo: CFOG30T_01-40-09.mp4 | Início: 01:40:09 | Fim: 01:48:01
# [SEM] Vídeo: SEM_FOG_01.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_03.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_05.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_06.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_08.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_10.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_11.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_13.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_15.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_16.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_18.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_20.mp4 | Sem propaganda
# [COM] Vídeo: CFOG02T_00-11-26.mp4 | Início: 00:11:26 | Fim: 00:19:18
# [COM] Vídeo: CFOG04T_00-10-16.mp4 | Início: 00:10:16 | Fim: 00:18:08
# [COM] Vídeo: CFOG07T_01-10-00.mp4 | Início: 01:10:00 | Fim: 01:17:22
# [COM] Vídeo: CFOG09T_00-48-07.mp4 | Início: 00:48:07 | Fim: 00:55:29
# [COM] Vídeo: CFOG12T_01-03-15.mp4 | Início: 01:03:15 | Fim: 01:11:07
# [COM] Vídeo: CFOG14T_01-42-15.mp4 | Início: 01:42:15 | Fim: 01:50:07
# [COM] Vídeo: CFOG17T_01-20-11.mp4 | Início: 01:20:11 | Fim: 01:28:03
# [COM] Vídeo: CFOG19T_00-13-26.mp4 | Início: 00:13:26 | Fim: 00:21:18
# [COM] Vídeo: CFOG22T_00-30-15.mp4 | Início: 00:30:15 | Fim: 00:38:07
# [COM] Vídeo: CFOG24T_00-55-09.mp4 | Início: 00:55:09 | Fim: 01:03:01
# [COM] Vídeo: CFOG27T_01-28-13.mp4 | Início: 01:28:13 | Fim: 01:36:05
# [COM] Vídeo: CFOG29T_01-30-11.mp4 | Início: 01:30:11 | Fim: 01:38:03
# [SEM] Vídeo: SEM_FOG_02.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_04.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_07.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_09.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_12.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_14.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_17.mp4 | Sem propaganda
# [SEM] Vídeo: SEM_FOG_19.mp4 | Sem propaganda
# Arquivo DataSet_SoccerKeyFrame.csv gerado com sucesso!

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\mauron\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: openpyxl in c:\users\mauron\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\mauron\anaconda3\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mauron\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mauron\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: et_xmlfile in c:\users\mauron\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\mauron\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([os.path.join(video_path, video_name), start_time, end_time, "Informar Patrocinador"])
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([os.path.join(video_path, video_name), None, None, "Sem propaganda"])
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Convertendo dados para DataFrame do pandas
df = pd.DataFrame(data[1:], columns=data[0])  # Ignora o cabeçalho

# Salvando arquivo Excel
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)

print("Arquivo DataSet_SoccerKeyFrame.xlsx gerado com sucesso!")
# Out:
# Arquivo DataSet_SoccerKeyFrame.xlsx gerado com sucesso!

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "LEARN_COM": "C:/DataSet_SoccerKeyFrame/LEARN/LE_C_FOG/",
    "LEARN_Sem": "C:/DataSet_SoccerKeyFrame/LEARN/LE_S_FOG/",
    "CHECK_COM": "C:/DataSet_SoccerKeyFrame/CHECK/CH_C_FOG/",
    "CHECK_Sem": "C:/DataSet_SoccerKeyFrame/CHECK/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description", "video_duration", "video_format", 
             "video_codec", "frame_size", "file_size"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Especificações do vídeo
video_duration = "2 min"
video_format = ".MP4"
video_codec = "H.264"
frame_size = "1920 x 1080"

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            file_path = os.path.join(video_path, video_name)
            file_size = os.path.getsize(file_path)  # Obtém o tamanho do arquivo em bytes
            
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([file_path, start_time, end_time, "Informar Patrocinador", 
                                  video_duration, video_format, video_codec, frame_size, file_size])
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([file_path, None, None, "Sem propaganda",
                                  video_duration, video_format, video_codec, frame_size, file_size])
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["LEARN_COM"], True)
process_videos(video_paths["LEARN_Sem"], False)
process_videos(video_paths["CHECK_COM"], True)
process_videos(video_paths["CHECK_Sem"], False)

# Convertendo dados para DataFrame do pandas
df = pd.DataFrame(data[1:], columns=data[0])  # Ignora o cabeçalho

# Salvando arquivo CSV
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)

# Salvando arquivo Excel
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)

print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
# Out:
# Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID_COM": "C:/DataSet_SoccerKeyFrame/VALID/CH_C_FOG/",
    "VALID_Sem": "C:/DataSet_SoccerKeyFrame/VALID/CH_S_FOG/",
    "TEST_COM": "C:/DataSet_SoccerKeyFrame/TEST/CH_C_FOG/",
    "TEST_Sem": "C:/DataSet_SoccerKeyFrame/TEST/CH_S_FOG/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description", "video_duration", "video_format", 
             "video_codec", "frame_size", "file_size_MB"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Especificações do vídeo
video_duration = "2 min"
video_format = ".MP4"
video_codec = "H.264"
frame_size = "1920 x 1080"

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            file_path = os.path.join(video_path, video_name)
            file_size_bytes = os.path.getsize(file_path)  # Obtém o tamanho do arquivo em bytes
            file_size_MB = file_size_bytes / (1024 * 1024)  # Converte bytes para megabytes
            
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([file_path, start_time, end_time, "Com_Foguete", 
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([file_path, None, None, "Sem propaganda",
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["TRAIN_COM"], True)
process_videos(video_paths["TRAIN_Sem"], False)
process_videos(video_paths["VALID_COM"], True)
process_videos(video_paths["VALID_Sem"], False)
process_videos(video_paths["TEST_COM"], True)
process_videos(video_paths["TEST_Sem"], False)

# Convertendo dados para DataFrame do pandas
df = pd.DataFrame(data[1:], columns=data[0])  # Ignora o cabeçalho

# Salvando arquivo CSV
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)

# Salvando arquivo Excel
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)

print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
# Out:
# Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN": "C:/DataSet_SoccerKeyFrame/TRAIN/",
    "VALID": "C:/DataSet_SoccerKeyFrame/VALID/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/",
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description", "video_duration", "video_format", 
             "video_codec", "frame_size", "file_size_MB"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Especificações do vídeo
video_duration = "2 min"
video_format = ".MP4"
video_codec = "H.264"
frame_size = "1920 x 1080"

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            file_path = os.path.join(video_path, video_name)
            file_size_bytes = os.path.getsize(file_path)  # Obtém o tamanho do arquivo em bytes
            file_size_MB = file_size_bytes / (1024 * 1024)  # Converte bytes para megabytes
            
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([file_path, start_time, end_time, "Com_Foguete", 
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([file_path, None, None, "Sem propaganda",
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["TRAIN"], True)
process_videos(video_paths["VALID"], True)
process_videos(video_paths["TEST"], True)

# Convertendo dados para DataFrame do pandas
df = pd.DataFrame(data[1:], columns=data[0])  # Ignora o cabeçalho

# Salvando arquivo CSV
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)

# Salvando arquivo Excel
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)

print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
# Out:
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_01.mp4
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_19.mp4
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_20.mp4
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38524\865653635.py in <module>
#      80
#      81 # Salvando arquivo Excel
# ---> 82 df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)
#      83
#      84 print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     886             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888             writer = ExcelWriter(  # type: ignore[abstract]
#     889                 writer, engine=engine, storage_options=storage_options
#     890             )
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1104         )
#    1105         if not isinstance(path, ExcelWriter):
# -> 1106             self.handles = get_handle(
#    1107                 path, mode, storage_options=storage_options, is_text=False
#    1108             )
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# PermissionError: [Errno 13] Permission denied: 'DataSet_SoccerKeyFrame.xlsx'

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID_COM": "C:/DataSet_SoccerKeyFrame/VALID/CH_C_FOG/",
    "VALID_Sem": "C:/DataSet_SoccerKeyFrame/VALID/CH_S_FOG/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Dados de exemplo
data = []
data.append(["video_path", "start_time", "end_time", "description", "video_duration", "video_format", 
             "video_codec", "frame_size", "file_size_MB"])

# Duração da propaganda
duration_seconds = 7
duration_frames = 22

# Especificações do vídeo
video_duration = "2 min"
video_format = ".MP4"
video_codec = "H.264"
frame_size = "1920 x 1080"

# Função para calcular start_time e end_time a partir do time code
def calculate_times(time_part):
    minutes, seconds, frames = map(int, time_part.split('-'))

    start_frame = (minutes * 60 + seconds) * 30 + frames  # Supondo que 30 fps

    end_seconds = seconds + duration_seconds
    end_frames = frames + duration_frames

    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames = end_frames % 30

    end_minutes = minutes + end_seconds // 60
    end_seconds = end_seconds % 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"

    return start_frame, start_time, end_time

# Função para processar vídeos
def process_videos(video_path, with_ads):
    for video_name in os.listdir(video_path):
        if video_name.endswith(".mp4"):  # Processa apenas arquivos MP4
            file_path = os.path.join(video_path, video_name)
            file_size_bytes = os.path.getsize(file_path)  # Obtém o tamanho do arquivo em bytes
            file_size_MB = file_size_bytes / (1024 * 1024)  # Converte bytes para megabytes
            
            if with_ads:  # Vídeos com propaganda
                if len(video_name) == 20:  # 16 caracteres + 4 para extensão
                    time_part = video_name[8:16]  # Pega os caracteres do time code
                    start_frame, start_time, end_time = calculate_times(time_part)
                    data.append([file_path, start_time, end_time, "Com_Foguete", 
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo com propaganda mal formatado: {video_name}")
            else:  # Vídeos sem propaganda
                if len(video_name) == 14:  # 10 caracteres + 4 para extensão
                    data.append([file_path, None, None, "Sem propaganda",
                                  video_duration, video_format, video_codec, frame_size, file_size_MB])
                else:
                    print(f"[ERRO] Vídeo sem propaganda mal formatado: {video_name}")

# Processando vídeos de todas as pastas
process_videos(video_paths["TRAIN_COM"], True)
process_videos(video_paths["TRAIN_Sem"], False)
process_videos(video_paths["VALID_COM"], True)
process_videos(video_paths["VALID_Sem"], False)
process_videos(video_paths["TEST"], True)

# Convertendo dados para DataFrame do pandas
df = pd.DataFrame(data[1:], columns=data[0])  # Ignora o cabeçalho

# Salvando arquivo CSV
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)

# Salvando arquivo Excel
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)

print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
# Out:
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_01.mp4
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_19.mp4
# [ERRO] Vídeo com propaganda mal formatado: SEM_FOG_20.mp4
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38524\2078939640.py in <module>
#      84
#      85 # Salvando arquivo Excel
# ---> 86 df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False)
#      87
#      88 print("Arquivo DataSet_SoccerKeyFrame.csv e DataSet_SoccerKeyFrame.xlsx gerados com sucesso!")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     886             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888             writer = ExcelWriter(  # type: ignore[abstract]
#     889                 writer, engine=engine, storage_options=storage_options
#     890             )
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1104         )
#    1105         if not isinstance(path, ExcelWriter):
# -> 1106             self.handles = get_handle(
#    1107                 path, mode, storage_options=storage_options, is_text=False
#    1108             )
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# PermissionError: [Errno 13] Permission denied: 'DataSet_SoccerKeyFrame.xlsx'

# %%
import pandas as pd
import os

# Caminhos corretos dos vídeos\n
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID_COM": "C:/DataSet_SoccerKeyFrame/VALID/CH_C_FOG/",
    "VALID_Sem": "C:/DataSet_SoccerKeyFrame/VALID/CH_S_FOG/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Lista para armazenar metadados
data = [[
    "video_path", "start_time", "end_time", "description", 
    "video_duration", "video_format", "video_codec", "frame_size", "file_size_MB"
]]

# Parâmetros de duração de propaganda
DURATION_SECONDS = 7
DURATION_FRAMES = 22

# Metadados fixos do vídeo
VIDEO_DURATION = "2 min"
VIDEO_FORMAT = ".MP4"
VIDEO_CODEC = "H.264"
FRAME_SIZE = "1920 x 1080"

# Função para converter timecode em tempos legíveis
def calculate_times(time_part: str):
    minutes, seconds, frames = map(int, time_part.split('-'))
    
    # Cálculo de início\ n    start_frame = (minutes * 60 + seconds) * 30 + frames
    
    # Cálculo de fim com rolagem de frames/segundos
    end_seconds = seconds + DURATION_SECONDS
    end_frames = frames + DURATION_FRAMES
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames %= 30
    
    end_minutes = minutes + end_seconds // 60
    end_seconds %= 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    return start_frame, start_time, end_time

# Função para processar cada pasta de vídeos
def process_videos(path: str, with_ads: bool = None):
    for filename in os.listdir(path):
        if not filename.lower().endswith('.mp4'):
            continue
        full_path = os.path.join(path, filename)
        size_mb = os.path.getsize(full_path) / (1024 * 1024)

        # Pasta TEST: both with and without ads
        if with_ads is None:
            if 'FOG' in filename.upper():
                time_part = filename[8:16]
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
            else:
                start_time, end_time, desc = None, None, 'Sem propaganda'
            data.append([full_path, start_time, end_time, desc,
                         VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])

        # Pastas separadas de COM e SEM
        elif with_ads:
            if len(filename) == 20:
                time_part = filename[8:16]
                _, start_time, end_time = calculate_times(time_part)
                data.append([full_path, start_time, end_time, 'Com_Foguete',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo com propaganda mal formatado: {filename}")
        else:
            if len(filename) == 14:
                data.append([full_path, None, None, 'Sem propaganda',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo sem propaganda mal formatado: {filename}")

# Processamento das pastas
process_videos(video_paths['TRAIN_COM'], True)
process_videos(video_paths['TRAIN_Sem'], False)
process_videos(video_paths['VALID_COM'], True)
process_videos(video_paths['VALID_Sem'], False)
process_videos(video_paths['TEST'])

# Criação do DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Salvando arquivos de forma segura
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False, engine='openpyxl')

print("Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38524\562164012.py in <module>
#      83
#      84 # Processamento das pastas
# ---> 85 process_videos(video_paths['TRAIN_COM'], True)
#      86 process_videos(video_paths['TRAIN_Sem'], False)
#      87 process_videos(video_paths['VALID_COM'], True)
#
# ~\AppData\Local\Temp\ipykernel_38524\562164012.py in process_videos(path, with_ads)
#      70             if len(filename) == 20:
#      71                 time_part = filename[8:16]
# ---> 72                 _, start_time, end_time = calculate_times(time_part)
#      73                 data.append([full_path, start_time, end_time, 'Com_Foguete',
#      74                              VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
#
# ~\AppData\Local\Temp\ipykernel_38524\562164012.py in calculate_times(time_part)
#      45     start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
#      46     end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
# ---> 47     return start_frame, start_time, end_time
#      48
#      49 # Função para processar cada pasta de vídeos
#
# NameError: name 'start_frame' is not defined

# %%
#python
import pandas as pd
import os

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID_COM": "C:/DataSet_SoccerKeyFrame/VALID/CH_C_FOG/",
    "VALID_Sem": "C:/DataSet_SoccerKeyFrame/VALID/CH_S_FOG/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Lista para armazenar metadados
data = [[
    "video_path", "start_time", "end_time", "description", 
    "video_duration", "video_format", "video_codec", "frame_size", "file_size_MB"
]]

# Parâmetros de duração de propaganda
DURATION_SECONDS = 7
DURATION_FRAMES = 22

# Metadados fixos do vídeo
VIDEO_DURATION = "2 min"
VIDEO_FORMAT = ".MP4"
VIDEO_CODEC = "H.264"
FRAME_SIZE = "1920 x 1080"

# Função para converter timecode em tempos legíveis
def calculate_times(time_part: str):
    minutes, seconds, frames = map(int, time_part.split('-'))
    # Cálculo de início em frames
    start_frame = (minutes * 60 + seconds) * 30 + frames

    # Cálculo de fim com rolagem de frames/segundos
    end_seconds = seconds + DURATION_SECONDS
    end_frames = frames + DURATION_FRAMES
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames %= 30

    end_minutes = minutes + end_seconds // 60
    end_seconds %= 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    return start_frame, start_time, end_time

# Função para processar cada pasta de vídeos
def process_videos(path: str, with_ads: bool = None):
    for filename in os.listdir(path):
        if not filename.lower().endswith('.mp4'):
            continue
        full_path = os.path.join(path, filename)
        size_mb = os.path.getsize(full_path) / (1024 * 1024)

        # Pasta TEST: ambos com e sem propaganda
        if with_ads is None:
            if 'FOG' in filename.upper():
                time_part = filename[8:16]
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
            else:
                start_time, end_time, desc = None, None, 'Sem propaganda'
            data.append([full_path, start_time, end_time, desc,
                         VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])

        # Pastas separadas de COM e SEM
        elif with_ads:
            if len(filename) == 20:
                time_part = filename[8:16]
                _, start_time, end_time = calculate_times(time_part)
                data.append([full_path, start_time, end_time, 'Com_Foguete',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo com propaganda mal formatado: {filename}")
        else:
            if len(filename) == 14:
                data.append([full_path, None, None, 'Sem propaganda',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo sem propaganda mal formatado: {filename}")

# Processamento das pastas
process_videos(video_paths['TRAIN_COM'], True)
process_videos(video_paths['TRAIN_Sem'], False)
process_videos(video_paths['VALID_COM'], True)
process_videos(video_paths['VALID_Sem'], False)
process_videos(video_paths['TEST'])

# Criação do DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Salvando arquivos de forma segura
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False, engine='openpyxl')

print("Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38524\3391431450.py in <module>
#      88 process_videos(video_paths['VALID_COM'], True)
#      89 process_videos(video_paths['VALID_Sem'], False)
# ---> 90 process_videos(video_paths['TEST'])
#      91
#      92 # Criação do DataFrame
#
# ~\AppData\Local\Temp\ipykernel_38524\3391431450.py in process_videos(path, with_ads)
#      60             if 'FOG' in filename.upper():
#      61                 time_part = filename[8:16]
# ---> 62                 _, start_time, end_time = calculate_times(time_part)
#      63                 desc = 'Com_Foguete'
#      64             else:
#
# ~\AppData\Local\Temp\ipykernel_38524\3391431450.py in calculate_times(time_part)
#      30 # Função para converter timecode em tempos legíveis
#      31 def calculate_times(time_part: str):
# ---> 32     minutes, seconds, frames = map(int, time_part.split('-'))
#      33     # Cálculo de início em frames
#      34     start_frame = (minutes * 60 + seconds) * 30 + frames
#
# ValueError: invalid literal for int() with base 10: '01.mp4'

# %%
#python
import pandas as pd
import os
import re

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID_COM": "C:/DataSet_SoccerKeyFrame/VALID/CH_C_FOG/",
    "VALID_Sem": "C:/DataSet_SoccerKeyFrame/VALID/CH_S_FOG/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Lista para armazenar metadados
data = [[
    "video_path", "start_time", "end_time", "description", 
    "video_duration", "video_format", "video_codec", "frame_size", "file_size_MB"
]]

# Parâmetros de duração de propaganda
DURATION_SECONDS = 7
DURATION_FRAMES = 22

# Metadados fixos do vídeo
VIDEO_DURATION = "2 min"
VIDEO_FORMAT = ".MP4"
VIDEO_CODEC = "H.264"
FRAME_SIZE = "1920 x 1080"

# Regex para identificar timecode no nome (mm-ss-ff)
timecode_pattern = re.compile(r"^(?P<prefix>.{8})(?P<time>\d{2}-\d{2}-\d{2})\.mp4$", re.IGNORECASE)

# Função para converter timecode em tempos legíveis
def calculate_times(time_part: str):
    minutes, seconds, frames = map(int, time_part.split('-'))
    # Cálculo de início em frames
    start_frame = (minutes * 60 + seconds) * 30 + frames

    # Cálculo de fim com rolagem de frames/segundos
    end_seconds = seconds + DURATION_SECONDS
    end_frames = frames + DURATION_FRAMES
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames %= 30

    end_minutes = minutes + end_seconds // 60
    end_seconds %= 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    return start_frame, start_time, end_time

# Função para processar cada pasta de vídeos
def process_videos(path: str, with_ads: bool = None):
    for filename in os.listdir(path):
        if not filename.lower().endswith('.mp4'):
            continue

        full_path = os.path.join(path, filename)
        size_mb = os.path.getsize(full_path) / (1024 * 1024)

        # Pasta TEST: ambos com e sem propaganda
        if with_ads is None:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
                data.append([full_path, start_time, end_time, desc,
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                # Vídeos sem timecode são considerados sem propaganda
                data.append([full_path, None, None, 'Sem propaganda',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])

        # Pastas separadas de COM e SEM
        elif with_ads:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                data.append([full_path, start_time, end_time, 'Com_Foguete',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo com propaganda mal formatado: {filename}")
        else:
            # Sem propaganda: apenas arquivo sem timecode e extensão mp4
            if not timecode_pattern.match(filename):
                data.append([full_path, None, None, 'Sem propaganda',
                             VIDEO_DURATION, VIDEO_FORMAT, VIDEO_CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo sem propaganda mal formatado: {filename}")

# Processamento das pastas
process_videos(video_paths['TRAIN_COM'], True)
process_videos(video_paths['TRAIN_Sem'], False)
process_videos(video_paths['VALID_COM'], True)
process_videos(video_paths['VALID_Sem'], False)
process_videos(video_paths['TEST'])

# Criação do DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Salvando arquivos de forma segura
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False, engine='openpyxl')

print("Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!")
# Out:
# Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!

# %%
#python
# !pip install openpyxl
import pandas as pd
import os
import re

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID": "C:/DataSet_SoccerKeyFrame/VALID/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Lista para armazenar metadados
data = [[
    "video_path", "start_time", "end_time", "description", 
    "Duração", "Formato", "Codec", "Resolução", "size_MB"
]]

# Parâmetros de duração de propaganda
DURATION_SECONDS = 7
DURATION_FRAMES = 22

# Metadados fixos do vídeo
DURATION = "2 min"
FORMAT = ".MP4"
CODEC = "H.264"
FRAME_SIZE = "1920 x 1080"

# Regex para identificar timecode no nome (mm-ss-ff)
timecode_pattern = re.compile(r"^(?P<prefix>.{8})(?P<time>\d{2}-\d{2}-\d{2})\.mp4$", re.IGNORECASE)

# Função para converter timecode em tempos legíveis
def calculate_times(time_part: str):
    minutes, seconds, frames = map(int, time_part.split('-'))
    # Cálculo de início em frames
    start_frame = (minutes * 60 + seconds) * 30 + frames

    # Cálculo de fim com rolagem de frames/segundos
    end_seconds = seconds + DURATION_SECONDS
    end_frames = frames + DURATION_FRAMES
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames %= 30

    end_minutes = minutes + end_seconds // 60
    end_seconds %= 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    return start_frame, start_time, end_time

# Função para processar cada pasta de vídeos
def process_videos(path: str, with_ads: bool = None):
    for filename in os.listdir(path):
        if not filename.lower().endswith('.mp4'):
            continue

        full_path = os.path.join(path, filename)
        size_mb = os.path.getsize(full_path) / (1024 * 1024)

        # Pasta TEST: ambos com e sem propaganda
        if with_ads is None:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
                data.append([full_path, start_time, end_time, desc,
                             DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb])
            else:
                # Vídeos sem timecode são considerados sem propaganda
                data.append([full_path, None, None, 'Sem propaganda',
                             DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb])

        # Pastas separadas de COM e SEM
        elif with_ads:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                data.append([full_path, start_time, end_time, 'Com_Foguete',
                             DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo com propaganda mal formatado: {filename}")
        else:
            # Sem propaganda: apenas arquivo sem timecode e extensão mp4
            if not timecode_pattern.match(filename):
                data.append([full_path, None, None, 'Sem propaganda',
                             DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb])
            else:
                print(f"[ERRO] Vídeo sem propaganda mal formatado: {filename}")

# Processamento das pastas
process_videos(video_paths['TRAIN_COM'], True)
process_videos(video_paths['TRAIN_Sem'], False)
process_videos(video_paths['VALID'],)
process_videos(video_paths['TEST'])

# Criação do DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Salvando arquivos de forma segura
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False, engine='openpyxl')

print("Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!")
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!

# %%
# !pip install openpyxl
import pandas as pd
import os
import re

# Caminhos corretos dos vídeos
video_paths = {
    "TRAIN_COM": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_C_FOG/",
    "TRAIN_Sem": "C:/DataSet_SoccerKeyFrame/TRAIN/LE_S_FOG/",
    "VALID": "C:/DataSet_SoccerKeyFrame/VALID/",
    "TEST": "C:/DataSet_SoccerKeyFrame/TEST/"
}

# Lista para armazenar metadados
data = [[
    "video_path", "start_time", "end_time", "description", 
    "Duração", "Formato", "Codec", "Resolução", "size_MB"
]]

# Parâmetros de duração de propaganda
DURATION_SECONDS = 7
DURATION_FRAMES = 22

# Metadados fixos do vídeo
DURATION = "2 min"
FORMAT = ".MP4"
CODEC = "H.264"
FRAME_SIZE = "1920 x 1080"

# Regex para identificar timecode no nome (mm-ss-ff)
timecode_pattern = re.compile(
    r"^(?P<prefix>.{8})(?P<time>\d{2}-\d{2}-\d{2})\.mp4$",
    re.IGNORECASE
)

# Função para converter timecode em tempos legíveis
def calculate_times(time_part: str):
    minutes, seconds, frames = map(int, time_part.split('-'))
    start_frame = (minutes * 60 + seconds) * 30 + frames

    end_seconds = seconds + DURATION_SECONDS
    end_frames = frames + DURATION_FRAMES
    if end_frames >= 30:
        end_seconds += end_frames // 30
        end_frames %= 30

    end_minutes = minutes + end_seconds // 60
    end_seconds %= 60

    start_time = f"{minutes:02}:{seconds:02}:{frames:02}"
    end_time = f"{end_minutes:02}:{end_seconds:02}:{end_frames:02}"
    return start_frame, start_time, end_time

# Função para processar cada pasta de vídeos
def process_videos(path: str, with_ads: bool = None):
    for filename in os.listdir(path):
        if not filename.lower().endswith('.mp4'):
            continue

        full_path = os.path.join(path, filename)
        raw_size = os.path.getsize(full_path) / (1024 * 1024)
        size_mb = round(raw_size, 1)  # Apenas uma casa decimal

        if with_ads is None:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
            else:
                start_time, end_time, desc = None, None, 'Sem propaganda'

            data.append([
                full_path, start_time, end_time, desc,
                DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb
            ])

        elif with_ads:
            match = timecode_pattern.match(filename)
            if match:
                time_part = match.group('time')
                _, start_time, end_time = calculate_times(time_part)
                desc = 'Com_Foguete'
                data.append([
                    full_path, start_time, end_time, desc,
                    DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb
                ])
            else:
                print(f"[ERRO] Vídeo com propaganda mal formatado: {filename}")

        else:
            match = timecode_pattern.match(filename)
            if not match:
                data.append([
                    full_path, None, None, 'Sem propaganda',
                    DURATION, FORMAT, CODEC, FRAME_SIZE, size_mb
                ])
            else:
                print(f"[ERRO] Vídeo sem propaganda mal formatado: {filename}")

# Processamento das pastas
process_videos(video_paths['TRAIN_COM'], True)
process_videos(video_paths['TRAIN_Sem'], False)
process_videos(video_paths['VALID'])
process_videos(video_paths['TEST'])

# Criação do DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Salvando arquivos de forma segura
df.to_csv('DataSet_SoccerKeyFrame.csv', index=False)
df.to_excel('DataSet_SoccerKeyFrame.xlsx', index=False, engine='openpyxl')

print("Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!")
# Out:
# Requirement already satisfied: openpyxl in c:\users\mauron\anaconda3\envs\soccer-yolo\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\mauron\anaconda3\envs\soccer-yolo\lib\site-packages (from openpyxl) (2.0.0)
# Arquivos gerados: DataSet_SoccerKeyFrame.csv e .xlsx com sucesso!
